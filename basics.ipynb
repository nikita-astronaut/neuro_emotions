# %%
import mne
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.use('Qt4Agg')

# %matplotlib inline
raw = mne.io.read_raw_brainvision("./resting_state/zavrin_open_eyes_eeg_15021500.vhdr")

data, times = raw.get_data(return_times = True)
plt.plot(times[:1000], data[34, :1000])

# raw.plot(block = True, order = [35], duration = 1.0, start = 0.0, n_channels = 1)
# Out:
# Extracting parameters from ./resting_state/zavrin_open_eyes_eeg_15021500.vhdr...
# Setting channel info structure...
